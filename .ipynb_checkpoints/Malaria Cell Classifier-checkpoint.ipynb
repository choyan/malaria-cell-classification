# %% [markdown]
# # Maleria parasitized cell detection

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import *

# %%
bs = 32
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %%
path = Path('/media/choyan/Work & Education/Data Science Materials/Datasets/Maleria Cells/cell_images')
path.ls()
# Out:
# [PosixPath('/media/choyan/Work & Education/Data Science Materials/Datasets/Maleria Cells/cell_images/models'),
#  PosixPath('/media/choyan/Work & Education/Data Science Materials/Datasets/Maleria Cells/cell_images/Parasitized'),
#  PosixPath('/media/choyan/Work & Education/Data Science Materials/Datasets/Maleria Cells/cell_images/Uninfected')]

# %%
classes = ['Parasitized', 'Uninfected']

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['Parasitized', 'Uninfected']
# (2, 2)

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['Parasitized', 'Uninfected'], 2, 22044, 5511)

# %%
learn = create_cnn(data, models.resnet34, metrics=accuracy)

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(6)
# Out:
# Total time: 1:15:52 <p><table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.105324</th>
#     <th>0.098845</th>
#     <th>0.963346</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.139909</th>
#     <th>0.108481</th>
#     <th>0.961350</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.117589</th>
#     <th>0.106890</th>
#     <th>0.964435</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.107919</th>
#     <th>0.090776</th>
#     <th>0.968245</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.074437</th>
#     <th>0.086405</th>
#     <th>0.967701</th>
#   </tr>
#   <tr>
#     <th>6</th>
#     <th>0.083026</th>
#     <th>0.085065</th>
#     <th>0.968608</th>
#   </tr>
# </table>

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(6,6), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Uninfected', 'Parasitized', 90), ('Parasitized', 'Uninfected', 83)]

# %%
learn.save('final-model')
